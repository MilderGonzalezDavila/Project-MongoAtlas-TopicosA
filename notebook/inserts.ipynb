# %% [markdown]
# # Insertar datos

# %%
from Connect import db
libros = db.libros

libro = {
    'Titulo' : 'La ciudad verde',
    'Autor' : 'Mario Vargas Llosa',
    'Anio' : 1965,
    'Categoria' : ['Novela', 'Peruana'],
    'Stock' : 4
}

#Insertamos en el documento una fila
res = libros.insert_one(libro)
print('Inserted ID', res.inserted_id)

#En el caso de OperationFailure Traceback (most recent call last), debemos verificar los permisos y la contraseña del usuario, debe ser la correcta
# Out:
# Inserted ID 690e20f0acae0b7429928ec0
