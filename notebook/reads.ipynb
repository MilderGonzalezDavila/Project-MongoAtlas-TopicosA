# %% [markdown]
# # Realizando consultas

# %%
from Connect import db
from bson.objectid import ObjectId # para mostrar en forma correcta los IDs

resultados = db.libros

# Buscar todos los documentos
for doc in resultados.find():
    print(doc)
# Out:
# {'_id': ObjectId('690e1f6dacae0b7429928ebd'), 'Titulo': 'La ciudad verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Peruana'], 'Stock': 4}
# {'_id': ObjectId('690e1f80acae0b7429928ebe'), 'Titulo': 'La ciudad verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Peruana'], 'Stock': 4}
# {'_id': ObjectId('690e20baacae0b7429928ebf'), 'Titulo': 'La ciudad verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Peruana'], 'Stock': 4}
# {'_id': ObjectId('690e20f0acae0b7429928ec0'), 'Titulo': 'La ciudad verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Peruana'], 'Stock': 4}
# {'_id': ObjectId('690e2288acae0b7429928ec1'), 'Titulo': 'La ciudad verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Peruana'], 'Stock': 4}
# {'_id': ObjectId('690e228eacae0b7429928ec2'), 'Titulo': 'La ciudad y los Perros', 'Autor': 'Mario Vargas Llosa', 'Anio': 1963, 'Categoria': ['Novela', 'Peruana'], 'Stock': 4}
# {'_id': ObjectId('690e228eacae0b7429928ec3'), 'Titulo': 'Don Quijote', 'Autor': 'Miguel de Cervantes Saavedra', 'Anio': 1963, 'Categoria': ['Novela', 'España'], 'Stock': 1}
# {'_id': ObjectId('690e237dacae0b7429928ec4'), 'titulo': '1984', 'autor': 'George Orwell', 'anio': 1949, 'generos': ['distopía', 'ciencia ficción', 'política'], 'prestado': True, 'editorial': {'nombre': 'Secker & Warburg', 'pais': 'Reino Unido'}}
# {'_id': ObjectId('690e237dacae0b7429928ec5'), 'titulo': 'Fahrenheit 451', 'autor': 'Ray Bradbury', 'anio': 1953, 'generos': ['ciencia ficción', 'distopía'], 'prestado': False, 'editorial': {'nombre': 'Ballantine Books', 'pais': 'EE.UU.'}}
# {'_id': ObjectId('690e237dacae0b7429928ec6'), 'titulo': 'El nombre del viento', 'autor': 'Patrick Rothfuss', 'anio': 2007, 'generos': ['fantasía', 'aventura'], 'prestado': True}
# {'_id': ObjectId('690e237dacae0b7429928ec7'), 'titulo': 'Dune', 'autor': 'Frank Herbert', 'anio': 1965, 'generos': ['ciencia ficción', 'política', 'religión'], 'prestado': False, 'editorial': {'nombre': 'Chilton Books', 'pais': 'EE.UU.'}}
# {'_id': ObjectId('690e237dacae0b7429928ec8'), 'titulo': 'Orgullo y prejuicio', 'autor': 'Jane Austen', 'anio': 1813, 'generos': ['romance', 'clásico'], 'prestado': False}
# {'_id': ObjectId('690e237dacae0b7429928ec9'), 'titulo': 'El resplandor', 'autor': 'Stephen King', 'anio': 1977, 'generos': ['terror', 'suspense'], 'prestado': True}
# {'_id': ObjectId('690e237dacae0b7429928eca'), 'titulo': 'Neuromante', 'autor': 'William Gibson', 'anio': 1984, 'generos': ['ciencia ficción', 'ciberpunk'], 'prestado': False}
# {'_id': ObjectId('690e237dacae0b7429928ecb'), 'titulo': 'Crónicas marcianas', 'autor': 'Ray Bradbury', 'anio': 1950, 'generos': ['ciencia ficción', 'cuentos'], 'prestado': True}
# {'_id': ObjectId('690e237dacae0b7429928ecc'), 'titulo': 'Cien años de soledad', 'autor': 'Gabriel García Márquez', 'anio': 1967, 'generos': ['realismo mágico', 'novela'], 'prestado': False, 'editorial': {'nombre': 'Sudamericana', 'pais': 'Argentina'}}
# {'_id': ObjectId('690e237dacae0b7429928ecd'), 'titulo': 'El código Da Vinci', 'autor': 'Dan Brown', 'anio': 2003, 'generos': ['misterio', 'thriller'], 'prestado': True}
# {'_id': ObjectId('690e237dacae0b7429928ece'), 'titulo': 'Matar un ruiseñor', 'autor': 'Harper Lee', 'anio': 1960, 'generos': ['drama', 'clásico'], 'prestado': False}
# {'_id': ObjectId('690e237dacae0b7429928ecf'), 'titulo': 'La ladrona de libros', 'autor': 'Markus Zusak', 'anio': 2005, 'generos': ['histórica', 'drama'], 'prestado': True}
# {'_id': ObjectId('690e237dacae0b7429928ed0'), 'titulo': 'Fundación', 'autor': 'Isaac Asimov', 'anio': 1951, 'generos': ['ciencia ficción', 'space opera'], 'prestado': False}
# {'_id': ObjectId('690e237dacae0b7429928ed1'), 'titulo': 'El hobbit', 'autor': 'J.R.R. Tolkien', 'anio': 1937, 'generos': ['fantasía', 'aventura'], 'prestado': True}
# {'_id': ObjectId('690e237dacae0b7429928ed2'), 'titulo': 'Rebelión en la granja', 'autor': 'George Orwell', 'anio': 1945, 'generos': ['satira', 'política', 'clásico'], 'prestado': False}
# {'_id': ObjectId('690e237dacae0b7429928ed3'), 'titulo': 'El perfume', 'autor': 'Patrick Süskind', 'anio': 1985, 'generos': ['histórica', 'drama', 'misterio'], 'prestado': True}
# {'_id': ObjectId('690e237dacae0b7429928ed4'), 'titulo': 'Sapiens: De animales a dioses', 'autor': 'Yuval Noah Harari', 'anio': 2011, 'generos': ['ensayo', 'historia', 'no ficción'], 'prestado': False}
# {'_id': ObjectId('690e237dacae0b7429928ed5'), 'titulo': 'El alquimista', 'autor': 'Paulo Coelho', 'anio': 1988, 'generos': ['filosófica', 'aventura'], 'prestado': True}
# {'_id': ObjectId('690e237dacae0b7429928ed6'), 'titulo': 'Blade Runner (¿Sueñan los androides con ovejas eléctricas?)', 'autor': 'Philip K. Dick', 'anio': 1968, 'generos': ['ciencia ficción', 'filosófica'], 'prestado': False}
# {'_id': ObjectId('690e237dacae0b7429928ed7'), 'titulo': 'Cumbres borrascosas', 'autor': 'Emily Brontë', 'anio': 1847, 'generos': ['romance', 'gótico', 'clásico'], 'prestado': True}

# %%
# Buscar por autor
for doc in resultados.find({"autor": "Gabriel García Márquez"}):
    print(doc['titulo'], "-", doc['autor'])
# Out:
# Cien años de soledad - Gabriel García Márquez

# %%
# Consulta muesta libros mayore tal anio 1993
for doc in resultados.find({"anio": {"$gt": 1960}}):
    print(doc['titulo'], "-", doc['anio'])
# Out:
# El nombre del viento - 2007
# Dune - 1965
# El resplandor - 1977
# Neuromante - 1984
# Cien años de soledad - 1967
# El código Da Vinci - 2003
# La ladrona de libros - 2005
# El perfume - 1985
# Sapiens: De animales a dioses - 2011
# El alquimista - 1988
# Blade Runner (¿Sueñan los androides con ovejas eléctricas?) - 1968

# %%
# Consulta muestra libros entre 1990 y 2000
for doc in resultados.find({"anio": {"$gte": 1980, "$lte": 2000}}):
    print(doc['titulo'], "-", doc['anio'])
# Out:
# Neuromante - 1984
# El perfume - 1985
# El alquimista - 1988

# %%
#Listar los libro de ciencia ficcion
for doc in resultados.find({"generos": "ciencia ficción"}):
    print(doc['titulo'], "-", doc['generos'])
# Out:
# 1984 - ['distopía', 'ciencia ficción', 'política']
# Fahrenheit 451 - ['ciencia ficción', 'distopía']
# Dune - ['ciencia ficción', 'política', 'religión']
# Neuromante - ['ciencia ficción', 'ciberpunk']
# Crónicas marcianas - ['ciencia ficción', 'cuentos']
# Fundación - ['ciencia ficción', 'space opera']
# Blade Runner (¿Sueñan los androides con ovejas eléctricas?) - ['ciencia ficción', 'filosófica']

# %%
# Libros con stock mayora 2
for doc in resultados.find({"Stock": {"$gt": 2}}):
    print(doc['Titulo'], doc['Anio'], "Stock:", doc['Stock'])
# Out:
# La ciudad verde 1965 Stock: 4
# La ciudad verde 1965 Stock: 4
# La ciudad verde 1965 Stock: 4
# La ciudad verde 1965 Stock: 4
# La ciudad verde 1965 Stock: 4
# La ciudad y los Perros 1963 Stock: 4
