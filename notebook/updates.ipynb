# %% [markdown]
# # Actualizando datos

# %%
from Connect import db

modificar = db.libros

res = modificar.update_one(
    {"Titulo": "La ciudad verde"},   # filtro
    {"$inc": {"Stock": 10}}          # operador $inc con valor numérico
)

print("Documentos modificados:", res.modified_count)

for doc in modificar.find({"Titulo": "La ciudad verde"}):
    print(doc)
# Out:
# Conexión exitosa correctamente
# Documentos modificados: 1
# {'_id': ObjectId('690e1f6dacae0b7429928ebd'), 'Titulo': 'La ciudad verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Peruana'], 'Stock': 14}
# {'_id': ObjectId('690e1f80acae0b7429928ebe'), 'Titulo': 'La ciudad verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Peruana'], 'Stock': 4}
# {'_id': ObjectId('690e20baacae0b7429928ebf'), 'Titulo': 'La ciudad verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Peruana'], 'Stock': 4}
# {'_id': ObjectId('690e20f0acae0b7429928ec0'), 'Titulo': 'La ciudad verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Peruana'], 'Stock': 4}
# {'_id': ObjectId('690e2288acae0b7429928ec1'), 'Titulo': 'La ciudad verde', 'Autor': 'Mario Vargas Llosa', 'Anio': 1965, 'Categoria': ['Novela', 'Peruana'], 'Stock': 4}

# %%
for doc in modificar.find({"Titulo": "La ciudad verde"}):
    print(doc['Titulo'], "ahora hay ", doc['Stock'])
# Out:
# La ciudad verde ahora hay  14
# La ciudad verde ahora hay  4
# La ciudad verde ahora hay  4
# La ciudad verde ahora hay  4
# La ciudad verde ahora hay  4
